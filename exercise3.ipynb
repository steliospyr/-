# %% [markdown]
# <a href="https://colab.research.google.com/github/steliospyr/-/blob/main/exercise3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Άσκηση 1
#
# Φτιάξτε ένα σύνολο δεδομένων με πληροφορίες για 3 άρθρα από ένα δημοσιογραφικό site της επιλογής σας.
#
# Οι πληροφορίες για κάθε άρθρο, θα είναι:
# - τίτλος του άρθρου
# - url του άρθρου
# - συντάκτης του άρθρου
# - θεματική κατηγορία άρθρου
# - ημερομηνία δημοσίευσης του άρθρου
#
# Οι πληροφορίες για κάθε άρθρο θα τοποθετηθούν σε ένα λεξικό.
#
# Το σύνολο των δεδομένων της αρθρογραφίας των 3 άρθρων θα είναι μια λίστα, η οποία θα περιέχει τα 3 λεξικά.
#
# **Παράδειγμα λεξικού (dictionary) με πληροφορίες για ένα άρθρο**:
# ```
# articleD_1 = {
#   "title": "Συναγερμός για κρούσμα κροτωνογενούς εγκεφαλίτιδας στην Ελλάδα – Εγκύκλιος ΕΟΔΥ",
#   "url": "https://www.news247.gr/ygeia/sinagermos-gia-krousma-krotonogenous-egkefalitidas-stin-ellada-egkiklios-eodi/",
#   "author": "ΓΙΑΝΝΗΣ ΔΕΒΕΤΖΟΓΛΟΥ",
#   "section": "Υγεία",
#   "date": "27 Μαρτίου 2025 13:40"
# }
# ```
#
# **Hints & Tips:**
# - αρχικά μπορείτε να δημιουργήσετε μια κενή λίστα με όνομα π.χ. "articlesL"
# - στη συνέχεια μπορείτε να δημιουργείτε ένα-ένα τα λεξικά με τις πληροφορίες για τα άρθρα (όπως στο παραπάνω παράδειγμα) και
# - να προσθέτε ένα-ένα τα λεξικά στη λίστα με append()
# - τέλος, καλέστε τη λίστα των άρθρων με το όνομά της για να εμφανιστεί στην οθόνη (μπορείτε να την κάνετε και print για να δείτε τη διαφορά στον τρόπο που εμφανίζεται η λίστα στην οθόνη)

# %%
articlesL = []

articleD_1 = {
    "title" : "Οι Αμερικανοί έστειλαν άνδρα στην περιβόητη φυλακή του Ελ Σαλβαδόρ λόγω «διοικητικού σφάλματος»",
    "url" : "https://www.lifo.gr/now/world/oi-amerikanoi-esteilan-andra-stin-periboiti-fylaki-toy-el-salbador-logo-dioikitikoy",
    "author" : "Δημήτρης Παπαδόπουλος",
    "section" : "διεθνή",
    "date" : "4/2/2025 00:25"
    }

articleD_2 = {
    "title" : "Νέα σύγκρουση οπαδών στη Θεσσαλονίκη – Ρίψη αναμμένου πυρσού σε όχημα",
    "url" : "https://www.lifo.gr/now/greece/nea-sygkroysi-opadon-sti-thessaloniki-ripsi-anammenoy-pyrsoy-se-ohima",
    "author" : "Ελένη Καραγιάννη",
    "section" : "Ελλάδα",
    "date" : "3/2/2025 11:57"
}

articleD_3 = {
    "title" : "Μητσοτάκης από το υπουργείο Εργασίας: Στηρίζουμε το διαθέσιμο εισόδημα όλων των συμπολιτών μας",
    "url" : "https://www.lifo.gr/now/politics/mitsotakis-apo-ypoyrgeio-ergasias-stirizoyme-diathesimo-eisodima-olon-ton-sympoliton",
    "author" : "Γιώργος Αντωνίου",
    "section" : "Πολιτική",
    "date" : "3/2/2025"

}

# %%
articlesL.append(articleD_1)
articlesL.append(articleD_2)
articlesL.append(articleD_3)
articlesL
# Out:
# [{'title': 'Οι Αμερικανοί έστειλαν άνδρα στην περιβόητη φυλακή του Ελ Σαλβαδόρ λόγω «διοικητικού σφάλματος»',
#   'url': 'https://www.lifo.gr/now/world/oi-amerikanoi-esteilan-andra-stin-periboiti-fylaki-toy-el-salbador-logo-dioikitikoy',
#   'author': 'Δημήτρης Παπαδόπουλος',
#   'section': 'διεθνή',
#   'date': '4/2/2025 00:25'},
#  {'title': 'Νέα σύγκρουση οπαδών στη Θεσσαλονίκη – Ρίψη αναμμένου πυρσού σε όχημα',
#   'url': 'https://www.lifo.gr/now/greece/nea-sygkroysi-opadon-sti-thessaloniki-ripsi-anammenoy-pyrsoy-se-ohima',
#   'author': 'Ελένη Καραγιάννη',
#   'section': 'Ελλάδα',
#   'date': '3/2/2025 11:57'},
#  {'title': 'Μητσοτάκης από το υπουργείο Εργασίας: Στηρίζουμε το διαθέσιμο εισόδημα όλων των συμπολιτών μας',
#   'url': 'https://www.lifo.gr/now/politics/mitsotakis-apo-ypoyrgeio-ergasias-stirizoyme-diathesimo-eisodima-olon-ton-sympoliton',
#   'author': 'Γιώργος Αντωνίου',
#   'section': 'Πολιτική',
#   'date': '3/2/2025'},
#  {'title': 'Οι Αμερικανοί έστειλαν άνδρα στην περιβόητη φυλακή του Ελ Σαλβαδόρ λόγω «διοικητικού σφάλματος»',
#   'url': 'https://www.lifo.gr/now/world/oi-amerikanoi-esteilan-andra-stin-periboiti-fylaki-toy-el-salbador-logo-dioikitikoy',
#   'author': 'Δημήτρης Παπαδόπουλος',
#   'section': 'διεθνή',
#   'date': '4/2/2025 00:25'},
#  {'title': 'Νέα σύγκρουση οπαδών στη Θεσσαλονίκη – Ρίψη αναμμένου πυρσού σε όχημα',
#   'url': 'https://www.lifo.gr/now/greece/nea-sygkroysi-opadon-sti-thessaloniki-ripsi-anammenoy-pyrsoy-se-ohima',
#   'author': 'Ελένη Καραγιάννη',
#   'section': 'Ελλάδα',
#   'date': '3/2/2025 11:57'},
#  {'title': 'Μητσοτάκης από το υπουργείο Εργασίας: Στηρίζουμε το διαθέσιμο εισόδημα όλων των συμπολιτών μας',
#   'url': 'https://www.lifo.gr/now/politics/mitsotakis-apo-ypoyrgeio-ergasias-stirizoyme-diathesimo-eisodima-olon-ton-sympoliton',
#   'author': 'Γιώργος Αντωνίου',
#   'section': 'Πολιτική',
#   'date': '3/2/2025'},
#  {'title': 'Οι Αμερικανοί έστειλαν άνδρα στην περιβόητη φυλακή του Ελ Σαλβαδόρ λόγω «διοικητικού σφάλματος»',
#   'url': 'https://www.lifo.gr/now/world/oi-amerikanoi-esteilan-andra-stin-periboiti-fylaki-toy-el-salbador-logo-dioikitikoy',
#   'author': 'Δημήτρης Παπαδόπουλος',
#   'section': 'διεθνή',
#   'date': '4/2/2025 00:25'},
#  {'title': 'Νέα σύγκρουση οπαδών στη Θεσσαλονίκη – Ρίψη αναμμένου πυρσού σε όχημα',
#   'url': 'https://www.lifo.gr/now/greece/nea-sygkroysi-opadon-sti-thessaloniki-ripsi-anammenoy-pyrsoy-se-ohima',
#   'author': 'Ελένη Καραγιάννη',
#   'section': 'Ελλάδα',
#   'date': '3/2/2025 11:57'},
#  {'title': 'Μητσοτάκης από το υπουργείο Εργασίας: Στηρίζουμε το διαθέσιμο εισόδημα όλων των συμπολιτών μας',
#   'url': 'https://www.lifo.gr/now/politics/mitsotakis-apo-ypoyrgeio-ergasias-stirizoyme-diathesimo-eisodima-olon-ton-sympoliton',
#   'author': 'Γιώργος Αντωνίου',
#   'section': 'Πολιτική',
#   'date': '3/2/2025'},
#  {'title': 'Οι Αμερικανοί έστειλαν άνδρα στην περιβόητη φυλακή του Ελ Σαλβαδόρ λόγω «διοικητικού σφάλματος»',
#   'url': 'https://www.lifo.gr/now/world/oi-amerikanoi-esteilan-andra-stin-periboiti-fylaki-toy-el-salbador-logo-dioikitikoy',
#   'author': 'Δημήτρης Παπαδόπουλος',
#   'section': 'διεθνή',
#   'date': '4/2/2025 00:25'},
#  {'title': 'Νέα σύγκρουση οπαδών στη Θεσσαλονίκη – Ρίψη αναμμένου πυρσού σε όχημα',
#   'url': 'https://www.lifo.gr/now/greece/nea-sygkroysi-opadon-sti-thessaloniki-ripsi-anammenoy-pyrsoy-se-ohima',
#   'author': 'Ελένη Καραγιάννη',
#   'section': 'Ελλάδα',
#   'date': '3/2/2025 11:57'},
#  {'title': 'Μητσοτάκης από το υπουργείο Εργασίας: Στηρίζουμε το διαθέσιμο εισόδημα όλων των συμπολιτών μας',
#   'url': 'https://www.lifo.gr/now/politics/mitsotakis-apo-ypoyrgeio-ergasias-stirizoyme-diathesimo-eisodima-olon-ton-sympoliton',
#   'author': 'Γιώργος Αντωνίου',
#   'section': 'Πολιτική',
#   'date': '3/2/2025'}]

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 2
#
# Μετατρέψτε τη λίστα με τα λεξικά που φτιάξατε στην προηγούμενη άσκηση σε pandas dataframe.
#
# **Hints & Tips:**
# - Εισάγετε τη βιβλιοθήκη pandas με την εντολή ```import pandas as pd```
# - Δημιουργήστε ένα dataframe με όνομα ```df```, με την εντολή ```df = pd.DataFrame(articlesL)```
# - Καλέστε το df για να εμφανιστεί στην οθόνη

# %%
import pandas as pd
df = pd.DataFrame(articlesL)
df
# Out:
#                                                 title  \
# 0   Οι Αμερικανοί έστειλαν άνδρα στην περιβόητη φυ...
# 1   Νέα σύγκρουση οπαδών στη Θεσσαλονίκη – Ρίψη αν...
# 2   Μητσοτάκης από το υπουργείο Εργασίας: Στηρίζου...
# 3   Οι Αμερικανοί έστειλαν άνδρα στην περιβόητη φυ...
# 4   Νέα σύγκρουση οπαδών στη Θεσσαλονίκη – Ρίψη αν...
# 5   Μητσοτάκης από το υπουργείο Εργασίας: Στηρίζου...
# 6   Οι Αμερικανοί έστειλαν άνδρα στην περιβόητη φυ...
# 7   Νέα σύγκρουση οπαδών στη Θεσσαλονίκη – Ρίψη αν...
# 8   Μητσοτάκης από το υπουργείο Εργασίας: Στηρίζου...
# 9   Οι Αμερικανοί έστειλαν άνδρα στην περιβόητη φυ...
# 10  Νέα σύγκρουση οπαδών στη Θεσσαλονίκη – Ρίψη αν...
# 11  Μητσοτάκης από το υπουργείο Εργασίας: Στηρίζου...
#
#                                                   url                 author  \
# 0   https://www.lifo.gr/now/world/oi-amerikanoi-es...  Δημήτρης Παπαδόπουλος
# 1   https://www.lifo.gr/now/greece/nea-sygkroysi-o...       Ελένη Καραγιάννη
# 2   https://www.lifo.gr/now/politics/mitsotakis-ap...       Γιώργος Αντωνίου
# 3   https://www.lifo.gr/now/world/oi-amerikanoi-es...  Δημήτρης Παπαδόπουλος
# 4   https://www.lifo.gr/now/greece/nea-sygkroysi-o...       Ελένη Καραγιάννη
# 5   https://www.lifo.gr/now/politics/mitsotakis-ap...       Γιώργος Αντωνίου
# 6   https://www.lifo.gr/now/world/oi-amerikanoi-es...  Δημήτρης Παπαδόπουλος
# 7   https://www.lifo.gr/now/greece/nea-sygkroysi-o...       Ελένη Καραγιάννη
# 8   https://www.lifo.gr/now/politics/mitsotakis-ap...       Γιώργος Αντωνίου
# 9   https://www.lifo.gr/now/world/oi-amerikanoi-es...  Δημήτρης Παπαδόπουλος
# 10  https://www.lifo.gr/now/greece/nea-sygkroysi-o...       Ελένη Καραγιάννη
# 11  https://www.lifo.gr/now/politics/mitsotakis-ap...       Γιώργος Αντωνίου
#
#      section            date
# 0     διεθνή  4/2/2025 00:25
# 1     Ελλάδα  3/2/2025 11:57
# 2   Πολιτική        3/2/2025
# 3     διεθνή  4/2/2025 00:25
# 4     Ελλάδα  3/2/2025 11:57
# 5   Πολιτική        3/2/2025
# 6     διεθνή  4/2/2025 00:25
# 7     Ελλάδα  3/2/2025 11:57
# 8   Πολιτική        3/2/2025
# 9     διεθνή  4/2/2025 00:25
# 10    Ελλάδα  3/2/2025 11:57
# 11  Πολιτική        3/2/2025

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 3 (intro)
#
# Στο site "ourworldindata.org" παρέχονται πάρα πολλά δεδομένα και γραφήματα για διάφορα topics για όλες τις χώρες του κόσμου.
#
# Για παράδειγμα, στη σελίδα https://ourworldindata.org/explorers/covid?Metric=Excess+mortality+%28estimates%29&Interval=Cumulative&Relative+to+population=false&country=USA~BRA~JPN~DEU, παρέχονται δεδομένα και γραφήματα σχετικά με την Covid-19.
#
# Αν επισκεφθείτε την παραπάνω σελίδα, επάνω αριστερά, υπάρχει ένας υπερσύνδεσμος με το κείμενο "Download this dataset". Εάν τον πατήσετε θα οδηγηθείτε στη σελίδα με τα datasets για τον covid.
#
# Πιο κάτω, σ' αυτή τη σελίδα, υπάρχει η ενότητα "Download data", με πολλά κουμπάκια download.
#
# Όταν πατήσετε κάποιο download μεταφέρεστε στη σελίδα του raw αρχείου csv με τα δεδομένα.
#
# Μπορούμε να φέρουμε αυτά τα δεδομένα σε ένα dataframe στην Python, με την παρακάτω εντολή:

# %%
import pandas as pd

covid_df = pd.read_csv("https://catalog.ourworldindata.org/garden/covid/latest/cases_deaths/cases_deaths.csv")
covid_df
# Out:
#             country        date  new_cases  total_cases  new_deaths  \
# 0       Afghanistan  2020-01-04        0.0            0         0.0
# 1       Afghanistan  2020-01-05        0.0            0         0.0
# 2       Afghanistan  2020-01-06        0.0            0         0.0
# 3       Afghanistan  2020-01-07        0.0            0         0.0
# 4       Afghanistan  2020-01-08        0.0            0         0.0
# ...             ...         ...        ...          ...         ...
# 471245     Zimbabwe  2025-02-26        0.0       266410         0.0
# 471246     Zimbabwe  2025-02-27        0.0       266410         0.0
# 471247     Zimbabwe  2025-02-28        0.0       266410         0.0
# 471248     Zimbabwe  2025-03-01        0.0       266410         0.0
# 471249     Zimbabwe  2025-03-02        0.0       266410         0.0
#
#         total_deaths  weekly_cases  weekly_deaths  weekly_pct_growth_cases  \
# 0                  0           NaN            NaN                      NaN
# 1                  0           NaN            NaN                      NaN
# 2                  0           NaN            NaN                      NaN
# 3                  0           NaN            NaN                      NaN
# 4                  0           NaN            NaN                      NaN
# ...              ...           ...            ...                      ...
# 471245          5740           0.0            0.0                      NaN
# 471246          5740           0.0            0.0                      NaN
# 471247          5740           0.0            0.0                      NaN
# 471248          5740           0.0            0.0                      NaN
# 471249          5740           0.0            0.0                      NaN
#
#         weekly_pct_growth_deaths  ...  cfr_100_cases  cfr_short_term  \
# 0                            NaN  ...            NaN             NaN
# 1                            NaN  ...            NaN             NaN
# 2                            NaN  ...            NaN             NaN
# 3                            NaN  ...            NaN             NaN
# 4                            NaN  ...            NaN             NaN
# ...                          ...  ...            ...             ...
# 471245                       NaN  ...       2.154574             NaN
# 471246                       NaN  ...       2.154574             NaN
# 471247                       NaN  ...       2.154574             NaN
# 471248                       NaN  ...       2.154574             NaN
# 471249                       NaN  ...       2.154574             NaN
#
#         days_since_100_total_cases  days_since_5_total_deaths  \
# 0                            -86.0                      -91.0
# 1                            -85.0                      -90.0
# 2                            -84.0                      -89.0
# 3                            -83.0                      -88.0
# 4                            -82.0                      -87.0
# ...                            ...                        ...
# 471245                      1737.0                     1819.0
# 471246                      1738.0                     1820.0
# 471247                      1739.0                     1821.0
# 471248                      1740.0                     1822.0
# 471249                      1741.0                     1823.0
#
#         days_since_1_total_cases_per_million  \
# 0                                      -81.0
# 1                                      -80.0
# 2                                      -79.0
# 3                                      -78.0
# 4                                      -77.0
# ...                                      ...
# 471245                                1779.0
# 471246                                1780.0
# 471247                                1781.0
# 471248                                1782.0
# 471249                                1783.0
#
#         days_since_0_1_total_deaths_per_million  \
# 0                                         -91.0
# 1                                         -90.0
# 2                                         -89.0
# 3                                         -88.0
# 4                                         -87.0
# ...                                         ...
# 471245                                   1819.0
# 471246                                   1820.0
# 471247                                   1821.0
# 471248                                   1822.0
# 471249                                   1823.0
#
#         days_since_100_total_cases_and_5m_pop  total_deaths_last12m  \
# 0                                       -86.0                   NaN
# 1                                       -85.0                   NaN
# 2                                       -84.0                   NaN
# 3                                       -83.0                   NaN
# 4                                       -82.0                   NaN
# ...                                       ...                   ...
# 471245                                 1737.0                   0.0
# 471246                                 1738.0                   0.0
# 471247                                 1739.0                   0.0
# 471248                                 1740.0                   0.0
# 471249                                 1741.0                   0.0
#
#         total_deaths_per_100k_last12m  total_deaths_per_million_last12m
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 471245                            0.0                               0.0
# 471246                            0.0                               0.0
# 471247                            0.0                               0.0
# 471248                            0.0                               0.0
# 471249                            0.0                               0.0
#
# [471250 rows x 40 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 3 (actual part)
#
# Βρείτε από το ourworldindata.org ένα dataset που σας ενδιαφέρει και ανοίξτε το σαν dataframe.

# %%
import pandas as pd
covidhosp_df = pd.read_csv("https://catalog.ourworldindata.org/garden/covid/latest/hospital/hospital.csv")
covidhosp_df
# Out:
#        country country_code        date  daily_occupancy_icu  \
# 0      Algeria          DZA  2020-07-17                 62.0
# 1      Algeria          DZA  2020-07-18                 67.0
# 2      Algeria          DZA  2020-07-20                 64.0
# 3      Algeria          DZA  2020-07-21                 56.0
# 4      Algeria          DZA  2020-07-22                 51.0
# ...        ...          ...         ...                  ...
# 46772    Wales     OWID_WLS  2023-07-08                  0.0
# 46773    Wales     OWID_WLS  2023-07-09                  0.0
# 46774    Wales     OWID_WLS  2023-07-10                  0.0
# 46775    Wales     OWID_WLS  2023-07-11                  0.0
# 46776    Wales     OWID_WLS  2023-07-12                  5.0
#
#        daily_occupancy_icu_per_1m  daily_occupancy_hosp  \
# 0                           1.381                   NaN
# 1                           1.492                   NaN
# 2                           1.425                   NaN
# 3                           1.247                   NaN
# 4                           1.136                   NaN
# ...                           ...                   ...
# 46772                       0.000                   0.0
# 46773                       0.000                   0.0
# 46774                       0.000                   0.0
# 46775                       0.000                   0.0
# 46776                       1.577                 142.0
#
#        daily_occupancy_hosp_per_1m  weekly_admissions_icu  \
# 0                              NaN                    NaN
# 1                              NaN                    NaN
# 2                              NaN                    NaN
# 3                              NaN                    NaN
# 4                              NaN                    NaN
# ...                            ...                    ...
# 46772                        0.000                    NaN
# 46773                        0.000                    NaN
# 46774                        0.000                    NaN
# 46775                        0.000                    NaN
# 46776                       44.795                    NaN
#
#        weekly_admissions_icu_per_1m  weekly_admissions_hosp  \
# 0                               NaN                     NaN
# 1                               NaN                     NaN
# 2                               NaN                     NaN
# 3                               NaN                     NaN
# 4                               NaN                     NaN
# ...                             ...                     ...
# 46772                           NaN                     2.0
# 46773                           NaN                     2.0
# 46774                           NaN                     2.0
# 46775                           NaN                     2.0
# 46776                           NaN                     5.0
#
#        weekly_admissions_hosp_per_1m
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 46772                          0.631
# 46773                          0.631
# 46774                          0.631
# 46775                          0.631
# 46776                          1.577
#
# [46777 rows x 11 columns]
