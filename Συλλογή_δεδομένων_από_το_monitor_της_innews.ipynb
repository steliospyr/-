# %% [markdown]
# <a href="https://colab.research.google.com/github/steliospyr/-/blob/main/%CE%A3%CF%85%CE%BB%CE%BB%CE%BF%CE%B3%CE%AE_%CE%B4%CE%B5%CE%B4%CE%BF%CE%BC%CE%AD%CE%BD%CF%89%CE%BD_%CE%B1%CF%80%CF%8C_%CF%84%CE%BF_monitor_%CF%84%CE%B7%CF%82_innews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ΒΗΜΑ 1. Πάμε στο site της innews

# %% [markdown]
# https://login.innews.gr/
#
# Κάνουμε login με τα credentials που μας έχουν δοθεί.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## ΒΗΜΑ 2. Ορισμός "θεματικών" κατηγοριών

# %% [markdown]
# Οι κατηγορίες (Categories) πρακτικά είναι οι όροι της αναζήτησης που θέτουμε ώστε να φιλτράρουμε τα δεδομένα της innews για να πάρουμε μόνο αυτά που μας ενδιαφέρουν.
#
# Αρχικά, στις Κατηγορίες βρίσκονται οι προκαθορισμένες "θεματικές" κατηγορίες που έχει φτιάξει η innews για εμας.
#
# Δεν μπορούμε να δημιουργήσουμε νέες κατηγορίες, αλλά μπορούμε να τροποποιήσουμε τις υπάρχουσες.

# %% [markdown]
# ### Τροποποίηση των Κατηγοριών, σύμφωνα με το θέμα που θέλουμε να μελετήσουμε στην εργασία μας
#
# - Από το αριστερό Menu πάμε στα **Settings** -> **Categories**
# - Διαλέγουμε μια Κατηγορία που δεν θέλουμε και πατάμε δεξια το **Edit**
# - Αλλάζουμε τον Τίτλο ώστε να αντιπροσωπεύει την κατηγορία που θέλουμε
# - Θέτουμε τα keywords βάσει των οποίων θα φιλτράρονται τα δεδομένα της innews ώστε να είναι σχετικά με το θέμα της Κατηγορίας μας
# - Πατάμε Save
#
# **Σημείωση:** Οι κανόνες για τον ορισμό των keywords περιγράφονται στο "How it works" που βρίσκεται δίπλα στον τίτλο CATEGORIES (στην κορυφή της σελίδας Settings -> Categories, όπου εμφανίζονται όλες οι κατηγορίες)

# %% [markdown]
# ## ΒΗΜΑ 3. Επιλογή δεδομένων

# %% [markdown]
# Από το αριστερό Menu πάμε στο **Categories** και επιλέγουμε την κατηγορία που θέλουμε.
#
# Στη σελίδα εμφανίζονται όλα τα αποτελέσματα που περιλαμβάνουν τα keywords που έχουμε θέσει για τη συγκεκριμένη κατηγορία.
#
# Τα αποτελέσματα αφορούν τη **σημερινή ημέρα** και προέρχονται από **όλα τα μέσα** που συλλέγει η Innews.

# %% [markdown]
# ### Επιλογή χρονικού διαστήματος
#
# Στην κορυφή της σελίδας μπορούμε να επιλέξουμε το χρονικό διάστημα που μας ενδιαφέρει:
# - Day (αποτελέσματα από τη σημερινή ημέρα)
# - 7days (αποτελέσματα από τις τελευταίες 7 ημέρες)
# - 15days
# - 30days
# - Choose date (ορίζουμε εμείς το χρονικό διάστημα που μας ενδιαφέρει)

# %% [markdown]
# ### Επιλογή (είδους) μέσων
#
# Ακριβώς κάτω από τις επιλογές του χρονικού διαστήματος, δεξιά υπάρχει το πράσινο κουμπί με τίτλο **Edit filters**.
#
# Από το menu **Media Types** επιλέγουμε το **Web** και πατάμε (στο κάτω μέρος της σελίδας) **Save filters**.

# %% [markdown]
# H σελίδα των αποτελεσμάτων ενημερώνεται ώστε να ανταποκρίνεται στις επιλογές που κάναμε.

# %% [markdown]
# ## ΒΗΜΑ 4. Κατέβασμα δεδομένων
#
# Στην ενότητα των αποτελεσμάτων (Results), υπάρχει ένα τετραγωνάκι επιλογής των αποτελεσμάτων.
# - το πατάμε και πατάμε **Yes** ώστε να επιλέξουμε όλα τα αποτελέσματα και όχι μόνο τα 50 πρώτα που εμφανίζονται στη σελίδα
#
# Δεξιά, υπάρχει το πορτοκαλί κουμπί **Export**.
# - τo πατάμε και επιλέγουμε **Excel**
#
# Τα δεδομένα κατεβαίνουν στον υπολογιστή μας.

# %% [markdown]
# ## ΒΗΜΑ 5. Προετοιμασία του excel
#
# - Ανοίγουμε Word το excel που κατεβάσαμε
# - Βρίσκουμε τη στήλη **Impact** και την πετάμε
# - Κάνουμε Save as (Αποθήκευση ως) .csv
# - Ανεβάζουμε το csv στο drive μας

# %% [markdown]
# ## ΒΗΜΑ 6. Διαχείριση του csv
#
# Φτιάχνουμε ένα νέο notebook και φέρνουμε το csv.

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/2025/Python 2025/report.csv")

# %%
df
# Out:
#      type           source                                              title  \
# 0     web   radiosecret.gr  ΣΥΡΙΖΑ – Νέα Αριστερά: «Ψήνεται» κοινό αίτημα ...
# 1     web   ilidakampos.gr  Οδεύει προς λύση το Πύργος - Τσακώνα με εξαίρε...
# 2     web    skaipatras.gr  Βουλή: Τρία αιτήματα για Προανακριτική Επιτροπ...
# 3     web  magnesianews.gr  Τα επιχειρήματα του ΠΑΣΟΚ για το αίτημα προανα...
# 4     web         ogdoo.gr           Τα πρωτοσέλιδα των εφημερίδων (21/05/25)
# ...   ...              ...                                                ...
# 4995  web        enikos.gr  Μαρινάκης: Fake news η αιτίαση ότι ανοίγουμε π...
# 4996  web       capital.gr  Π. Μαρινάκης: Ο Ν. Ανδρουλάκης εκτός από εξαφα...
# 4997  web         libre.gr  Κοκοτσάκης για πόρισμα Καρώνη:”Έωλο και ασαφές...
# 4998  web   tomanifesto.gr  Ντόρα Μπακογιάννη: Οι πολιτικοί δεν μπορεί να ...
# 4999  web     dikastiko.gr  Κ. Πιερρακάκης: Βάζουμε τέλος στις χρονοβόρες ...
#
# ...

# %% [markdown]
# Μπορούμε να δούμε ποια είναι τα sources (δηλαδή από ποια sites είναι τα δεδομένα μας)

# %%
df["source"].unique()
# Out:
# array(['radiosecret.gr', 'ilidakampos.gr', 'skaipatras.gr',
#        'magnesianews.gr', 'ogdoo.gr', 'newsit.gr', 'iapogevmatini.gr',
#        'capital.gr', 'esos.gr', 'sofokleous10.gr', 'newmoney.gr',
#        'rethemnos.gr', 'europost.gr', 'euro2day.gr', 'lesvospen.gr',
#        'dikastiko.gr', 'fimotro.gr', 'protothema.gr', 'thetoc.gr',
#        'mkdn.gr', 'thebest.gr', 'topontiki.gr', 'politic.gr',
#        'lykavitos.gr', 'tovima.gr', 'tomanifesto.gr', 'banksnews.gr',
#        'pressing.gr', 'patris.gr', 'agrinio2day.gr', 'gnomip.gr',
#        'hellasjournal.com', 'politeianews.gr', 'formedia.gr',
#        'vradini.gr', 'moneypress.gr', 'bankingnews.gr',
#        'kefaloniapress.gr', 'naftemporiki.gr', 'flamis.gr',
#        'newsbreak.gr', 'skai.gr', 'newpost.gr', 'thesstoday.gr',
#        'goodnet.gr', 'eleftherostypos.gr', 'pelop.gr', 'voria.gr',
#        'bci24news.com', 'pagenews.gr', 'flash.gr', 'real.gr',
# ...

# %%
# Μπορώ να δω πόσα sites είναι όλα
df.source.nunique()
# Out:
# 576

# %%
# Μπορώ να τα δω όλα
# df["source"].unique()
# Μπορώ να δω μόνο τα 10 πρώτα
sorted(list(df["source"].unique()))#[:10]
# Out:
# ['1069.gr',
#  '12nisospress.com',
#  '15minutes.gr',
#  '1voice.gr',
#  '42.gr',
#  '4press.gr',
#  '902.gr',
#  '94fm.gr',
#  'achaianews.gr',
#  'adieksodos.gr',
#  'aegeanews.gr',
#  'aeolos.tv',
#  'afirimeno.com',
#  'aftodioikisi.gr',
#  'agonaskritis.gr',
#  'agrinio24.gr',
#  'agrinio2day.gr',
#  'agrinioculture.gr',
#  'agrinionews.gr',
#  'agriniopress.gr',
#  'agrinioreport.com',
#  'agriniosite.gr',
#  'agriniotimes.gr',
#  'agro24.gr',
#  'agrocapital.gr',
#  'agroekfrasi.gr',
#  'agronews.gr',
#  'agrotypos.gr',
#  'aigiovoice.gr',
#  'aitoloakarnaniabest.gr',
#  'alfavita.gr',
#  'alithia.gr',
#  'alithianews.gr',
#  'allabouthealth.gr',
#  'alphafreepress.gr',
#  'alphatv.gr',
#  'alt.gr',
#  'amarysia.gr',
#  'amarysianotia.gr',
#  'amna.gr',
#  'anatropinews.gr',
#  'anexartitos.gr',
#  'anoixtoparathyro.gr',
#  'ant1news.gr',
#  'antenna.gr',
#  'anticorr.gr',
#  'antinews.gr',
#  'apotis4stis5.com',
#  'arcadiaportal.gr',
#  'ardin-rixi.gr',
# ...

# %% [markdown]
# Μπορούμε να δούμε πόσα άρθρα έχουμε από το κάθε site

# %%
df.groupby("source")['title'].count().reset_index().sort_values("title", ascending=False).head(20)
# Out:
#               source  title
# 59      athina984.gr     95
# 531   tomanifesto.gr     82
# 396  parapolitika.gr     69
# 131         efsyn.gr     63
# 39           amna.gr     60
# 420       politic.gr     53
# 69     bci24news.com     51
# 179        ethnos.gr     51
# 447     radiovera.gr     50
# 200      formedia.gr     49
# 239            in.gr     48
# 300       liberal.gr     44
# 533        tovima.gr     44
# 532     topontiki.gr     42
# 389      pagenews.gr     41
# 109         dnews.gr     40
# 301         libre.gr     39
# 293    larissanet.gr     39
# 428      pressing.gr     37
# 272    kontranews.gr     36

# %% [markdown]
# Μπορούμε να φτιάξουμε επιμέρους dataframes (1 για κάθε site που θέλουμε και να τα σώσουμε σαν csvs)

# %%
df[df["source"]=="efsyn.gr"]
# Out:
#      type    source                                              title  \
# 176   web  efsyn.gr  Ανάληψη ευθύνης για τις 4 επιθέσεις με γκαζάκι...
# 291   web  efsyn.gr                          Ο σκορπιός και ο βάτραχος
# 308   web  efsyn.gr  Προανακριτική χωρίς υστεροβουλίες και μικροκομ...
# 315   web  efsyn.gr  Ασφαλιστικά μέτρα Γενιδούνια κατά της απόλυσης...
# 409   web  efsyn.gr  Είναι ντροπή να μένουμε απαθείς μπροστά στη γε...
# ...   ...       ...                                                ...
# 4697  web  efsyn.gr                             Η πεντάδα της ανοησίας
# 4699  web  efsyn.gr                         «Η εξεγερμένη αξιοπρέπεια»
# 4729  web  efsyn.gr  Τέμπη: Θέλει η κυβέρνηση να «κρυφτεί» αλλά η.....
# 4797  web  efsyn.gr  Live η εκδήλωση στο ευρωκοινοβούλιο: Η Δημοσιο...
# 4927  web  efsyn.gr  Συνέχιση συνεργασίας στη Βουλή για το θέμα των...
#
#                                                    text categories sentiment  \
# ...

# %%
efsyn_df = df[df["source"]=="efsyn.gr"]
efsyn_df = efsyn_df.reset_index(drop=True)
efsyn_df
# efsyn_df.reset_index(drop=True, inplace=True)
# efsyn_df
# Out:
#    type    source                                              title  \
# 0   web  efsyn.gr  Ανάληψη ευθύνης για τις 4 επιθέσεις με γκαζάκι...
# 1   web  efsyn.gr                          Ο σκορπιός και ο βάτραχος
# 2   web  efsyn.gr  Προανακριτική χωρίς υστεροβουλίες και μικροκομ...
# 3   web  efsyn.gr  Ασφαλιστικά μέτρα Γενιδούνια κατά της απόλυσης...
# 4   web  efsyn.gr  Είναι ντροπή να μένουμε απαθείς μπροστά στη γε...
# ..  ...       ...                                                ...
# 58  web  efsyn.gr                             Η πεντάδα της ανοησίας
# 59  web  efsyn.gr                         «Η εξεγερμένη αξιοπρέπεια»
# 60  web  efsyn.gr  Τέμπη: Θέλει η κυβέρνηση να «κρυφτεί» αλλά η.....
# 61  web  efsyn.gr  Live η εκδήλωση στο ευρωκοινοβούλιο: Η Δημοσιο...
# 62  web  efsyn.gr  Συνέχιση συνεργασίας στη Βουλή για το θέμα των...
#
#                                                  text categories sentiment  \
# ...

# %%
# αποθήκευση σε csv
efsyn_df.to_csv("/content/drive/MyDrive/2025/Python 2025/innews_efsyn.csv", index=False)

# %% [markdown]
# Μπορούμε να σώσουμε ένα επιμέρους df που να περιέχει δεδομένα από περισσότερα από 1 sites

# %%
# Λίστα με τα sites που θέλουμε να κρατήσουμε
selected_sites = ['efsyn.gr', 'tovima.gr', 'amna.gr', 'ethnos.gr']
# Φιλτράρισμα του df
filtered_df = df[df['source'].isin(selected_sites)]
filtered_df.reset_index(drop=True, inplace=True)
filtered_df = filtered_df.sort_values("source").reset_index(drop=True)
filtered_df
# Out:
#     type     source                                              title  \
# 0    web    amna.gr  (Ξένη δημοσίευση) - ΑΝΑΚΟΙΝΩΣΗ ΤΥΠΟΥ - ΕΛΛΗΝΙΚ...
# 1    web    amna.gr  Βουλή: Kατατέθηκε η πρόταση του ΠΑΣΟΚ για ειδι...
# 2    web    amna.gr  (Ξένη δημοσίευση)- ΑΝΑΚΟΙΝΩΣΗ ΤΥΠΟΥ - ΠΑΣΟΚ - ...
# 3    web    amna.gr  «Είμαστε δεσμευμένοι να είμαστε η φωνή της δικ...
# 4    web    amna.gr  (Ξένη δημοσίευση)- ΑΝΑΚΟΙΝΩΣΗ ΤΥΠΟΥ - ΠΑΣΟΚ- Κ...
# ..   ...        ...                                                ...
# 213  web  tovima.gr  5 το πρωί: Στο κυνήγι της εκεχειρίας Πούτιν κα...
# 214  web  tovima.gr  Τέμπη: Στα ύψη η πολιτική αντιπαράθεση μετά το...
# 215  web  tovima.gr                   Τέμπη: Ήγγιγκεν η ώρα της κρίσης
# 216  web  tovima.gr  Σκληρή επίθεση Σαμαρά στην κυβέρνηση: Τα «ό,τι...
# 217  web  tovima.gr  ΠαΣοΚ: Επιχείρηση «ξέπλυμα Καραμανλή» – Οι 4 α...
#
#                                                   text categories sentiment  \
# ...

# %% [markdown]
# ---

# %%
filtered_df["source"].unique()
# Out:
# array(['efsyn.gr', 'tovima.gr'], dtype=object)

# %% [markdown]
# ## ΣΗΜΑΝΤΙΚΟ!!!
#
# Παρότι στα αποτελέσματα στο Monitor της innews μπορεί να μας λέει ότι υπάρχουν π.χ. 15.000 άρθρα, και παρότι του λέμε ότι θέλουμε να τα πάρουμε ΟΛΑ σε excel, το Monitor μας δίνει 5.000 άρθρα max.
#
# ### Γι' αυτό:
# - σπάμε το χρονικό διάστημα που θέλουμε σε μικρότερα συνεχόμενα χρονικά διαστήματα και κατεβάζουμε ένα-ένα όλα τα results
# - ανοίγουμε το καθένα από αυτά στο Word, πετάμε τη στήλη "Impact", σώζουμε σαν csv και ανεβάζουμε τα csvs στο drive
# - ΕΝΩΝΟΥΜΕ ΤΑ ΕΠΙΜΕΡΟΥΣ csvs ΜΕ ΤΟΝ ΠΑΡΑΚΑΤΩ ΤΡΟΠΟ

# %% [markdown]
# Φέρνουμε τα επιμέρους csvs

# %%
df2 = pd.read_csv("/content/drive/MyDrive/2025/Python 2025/report2.csv")
df2
# Out:
#    type                   source  \
# 0   web              newmoney.gr
# 1   web          magnesianews.gr
# 2   web      anoixtoparathyro.gr
# 3   web                empros.gr
# 4   web            emakedonia.gr
# 5   web             difernews.gr
# 6   web               creta24.gr
# 7   web         iapogevmatini.gr
# 8   web                   kke.gr
# 9   web               capital.gr
# 10  web  glyfadametropolitans.gr
# 11  web               creta24.gr
# 12  web            achaianews.gr
# 13  web             15minutes.gr
# 14  web                ethnos.gr
# 15  web               olympia.gr
# 16  web         rethemnosnews.gr
# 17  web           kozanimedia.gr
# 18  web             onlarissa.gr
# 19  web                   902.gr
# 20  web           tomanifesto.gr
# 21  web              neakriti.gr
# 22  web          aftodioikisi.gr
# 23  web            paraskhnio.gr
# 24  web             athina984.gr
# 25  web          nicemagazine.gr
# 26  web             toedolio5.gr
# ...

# %%
# τα ενώνουμε με concat - μέσα στη λίστα βάζουμε τα ονόματα των επιμέρους dfs
all_df = pd.concat([df, df2], axis=0, ignore_index=True)
all_df
# Out:
#      type           source                                              title  \
# 0     web   radiosecret.gr  ΣΥΡΙΖΑ – Νέα Αριστερά: «Ψήνεται» κοινό αίτημα ...
# 1     web   ilidakampos.gr  Οδεύει προς λύση το Πύργος - Τσακώνα με εξαίρε...
# 2     web    skaipatras.gr  Βουλή: Τρία αιτήματα για Προανακριτική Επιτροπ...
# 3     web  magnesianews.gr  Τα επιχειρήματα του ΠΑΣΟΚ για το αίτημα προανα...
# 4     web         ogdoo.gr           Τα πρωτοσέλιδα των εφημερίδων (21/05/25)
# ...   ...              ...                                                ...
# 5045  web   tomanifesto.gr              Κάνε κι εσύ κόμμα για να… εξαφανιστεί
# 5046  web          skai.gr  ΝΔ για παραβατικότητα ανηλίκων: Οφείλουμε να ε...
# 5047  web      euro2day.gr  ΠΑΣΟΚ: ΟΠΕΚΕΠΕ, ο καθρέφτης της διαφθοράς της ...
# 5048  web     lesvospen.gr                              ΠΑΣΟΚ και Συμπληγάδες
# 5049  web         radar.gr  Παίζει τα ρέστα του ο Φάμελλος για να ανακτήσε...
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/report (1).csv', encoding='cp1253')

# %%
df
# Out:
#     type           source                                              title  \
# 0    web      daynight.gr  Η Μάστιγα στα Χωριά του Ρεθύμνου: Οχήματα με 8...
# 1    web   iraklionews.gr  Σκηνικό τρόμου σε δρόμο της Κρήτης: Βυτιοφόρο ...
# 2    web        zougla.gr       Μηχανή παρέσυρε πεζό στην Αγία Μαρίνα Χανίων
# 3    web         seleo.gr  Κρήτη: Μηχανή παρέσυρε πεζό στα Χανιά – Δύο τρ...
# 4    web  maleviziotis.gr  Ακόμα ένα τροχαίο στην Κρήτη: Μηχανή παρέσυρε ...
# ..   ...              ...                                                ...
# 392  web   iraklionews.gr  Τροχαίο ατύχημα στην Κρήτη: Νταλίκα τούμπαρε λ...
# 393  web   iraklionews.gr  Κρήτη: Εκτροπή και ανατροπή κλούβας στην Εθνικ...
# 394  web         flash.gr  Χανιά: Σοβαρό τροχαίο με νταλίκα σε κεντρικό δ...
# 395  web     cretalive.gr  Τούμπαρε η νταλίκα πάνω στην εθνική - Από τύχη...
# 396  web      cretaone.gr  Κρήτη: Τούμπαρε νταλίκα με ντομάτες στην Παλαι...
#
# ...

# %%
df["source"].unique()
# Out:
# array(['daynight.gr', 'iraklionews.gr', 'zougla.gr', 'seleo.gr',
#        'maleviziotis.gr', 'makeleio.gr', 'thestival.gr', 'usay.gr',
#        'neakriti.gr', 'dete.gr', 'eleftherostypos.gr', 'athensvoice.gr',
#        'fonimaleviziou.gr', 'pronews.gr', 'real.gr', 'topontiki.gr',
#        'protothema.gr', 'fonien.gr', 'newmoney.gr', 'antenna.gr',
#        'ant1news.gr', 'creta24.gr', 'kriti360.gr', 'zarpanews.gr',
#        'parapolitika.gr', 'flash.gr', 'cretaone.gr', 'ekriti.gr',
#        'themakritis.gr', 'efsyn.gr', '94fm.gr', 'thebest.gr',
#        'news247.gr', 'newsbomb.gr', 'newshub.gr', '1069.gr',
#        'candiadoc.gr', 'galaksias.com', 'flashnews.gr', 'kontranews.gr',
#        'kerkyra.net', 'sofokleousin.gr', 'speedynews.gr', 'ieidiseis.gr',
#        'financialreport.gr', 'agriniopress.gr', 'huffingtonpost.gr',
#        'dikastiko.gr', 'cna.gr', 'pentapostagma.gr', 'libre.gr',
#        'radiosecret.gr', 'newsit.gr', 'ertnews.gr', 'nevronas.gr',
# ...

# %%
df.groupby("source")['title'].count().reset_index().sort_values("title", ascending=False).head(10)
# Out:
#              source  title
# 57   iraklionews.gr     54
# 22      daynight.gr     43
# 20      cretaone.gr     15
# 64      kriti360.gr     12
# 45        fonien.gr     12
# 73  maleviziotis.gr     11
# 75      neakriti.gr     11
# 17       creta24.gr      8
# 88  parapolitika.gr      7
# 96    protothema.gr      7

# %%
df[df["source"]=="iraklionews.gr"]
# Out:
#     type          source                                              title  \
# 1    web  iraklionews.gr  Σκηνικό τρόμου σε δρόμο της Κρήτης: Βυτιοφόρο ...
# 15   web  iraklionews.gr  Νέο τροχαίο στην Κρήτη: Μηχανή παρέσυρε πεζό –...
# 21   web  iraklionews.gr  Νέο τροχαίο στο Ηράκλειο: Σύγκρουση αυτοκινήτο...
# 36   web  iraklionews.gr  Νέο σοβαρό τροχαίο στην Κρήτη: Σφοδρή σύγκρουσ...
# 38   web  iraklionews.gr  Σοκ σε διάβαση πεζών: 13χρονος με πατίνι τραυμ...
# 43   web  iraklionews.gr  Ακόμη ένα τροχαίο στην Κρήτη: Μηχανάκι εξετράπ...
# 44   web  iraklionews.gr  Κρήτη: Νέο τροχαίο ατύχημα με τραυματισμό – Στ...
# 47   web  iraklionews.gr  Μηχανή «καρφώθηκε» σε λεωφορείο – Με σοβαρά τρ...
# 57   web  iraklionews.gr  Σύγκρουση-σοκ με έναν νεκρό και δύο τραυματίες...
# 58   web  iraklionews.gr  Τροχαίο με νεκρό 64χρονο – Έπεσε με βαν σε στα...
# 59   web  iraklionews.gr  Κρήτη: Τροχαίο με νεκρό 64χρονο – Έπεσε με βαν...
# ...

# %%
df[df["source"]=="protothema.gr"]
# Out:
#     type         source                                              title  \
# 19   web  protothema.gr    Μηχανή παρέσυρε πεζό στα Χανιά – Δύο τραυματίες
# 120  web  protothema.gr  Μία τραυματίας σε τροχαίο με γουρούνα στον ΒΟΑ...
# 202  web  protothema.gr  Σύγκρουση μηχανής με φορτηγό στο Ηράκλειο - Έν...
# 235  web  protothema.gr  Ηράκλειο: Εξιχνίαση τηλεφωνικής απάτης σε βάρο...
# 287  web  protothema.gr  Τουριστικό λεωφορείο συγκρούστηκε με αυτοκίνητ...
# 302  web  protothema.gr  Κρήτη: Τουριστικό λεωφορείο συγκρούστηκε με αυ...
# 370  web  protothema.gr  Βίντεο: Τροχαίο έξω από παιδικό σταθμό στην Αγ...
#
#                                                   text categories sentiment  \
# 19   Χανιά\nEKAB\nΤροχαίο\nΝέο τροχαίο ατύχημα σημε...    τροχαια   Neutral
# 120  Τροχαίο\nΤροχαίο ατύχημα\nΒΟΑΚ\nΓουρούνα\nΤροχ...    τροχαια   Neutral
# 202  Ηράκλειο\nΗράκλειο Κρήτης\nΤροχαίο ατύχημα\nΤρ...    τροχαια  Positive
# ...

# %%
df[df["source"]=="daynight.gr"]
# Out:
#     type       source                                              title  \
# 0    web  daynight.gr  Η Μάστιγα στα Χωριά του Ρεθύμνου: Οχήματα με 8...
# 8    web  daynight.gr  Απίστευτο τροχαίο στον Λαγκαδά Θεσσαλονίκης: Α...
